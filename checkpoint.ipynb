# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
pd.set_option('display.max_rows', 15)
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.10f}'.format)
pd.set_option('display.float_format', lambda x: ('%f' % x).rstrip('0').rstrip('.'))

# %%
df = pd.read_csv('sales_data.csv')

# %%
df.head()
# Out:
#        Order ID        Sale ID                       Date  Order  \
# 0 5539800000000 17401000000000  2024-01-01T14:06:18-05:00  #2069
# 1 5539800000000 17401000000000  2024-01-01T14:08:17-05:00  #2070
# 2 5539800000000 17401000000000  2024-01-01T14:08:17-05:00  #2070
# 3 5539970000000 17401500000000  2024-01-01T16:50:20-05:00  #2071
# 4 5539970000000 17401500000000  2024-01-01T16:50:20-05:00  #2071
#
#   Transaction type Sale type  Sales channel   POS location Billing country  \
# 0          product     order  Point of Sale  Boutique Site             NaN
# 1          product     order  Point of Sale  Boutique Site             NaN
# 2          product     order  Point of Sale  Boutique Site             NaN
# 3          product     order  Point of Sale  Boutique Site             NaN
# 4          product     order  Point of Sale  Boutique Site             NaN
#
#   Billing region Billing city Shipping country Shipping region Shipping city  \
# ...

# %%
df[(df['Gross sales'] != df['Net sales'])].head()
# Out:
#         Order ID        Sale ID                       Date  Order  \
# 17 5547170000000 17420000000000  2024-01-06T14:12:18-05:00  #2084
# 30 5547370000000 17420500000000  2024-01-06T16:58:34-05:00  #2089
# 64 5552290000000 17444600000000  2024-01-12T18:45:22-05:00  #2098
# 65 5552290000000 17441200000000  2024-01-12T18:45:22-05:00  #2098
# 66 5552290000000 17441200000000  2024-01-12T18:45:22-05:00  #2098
#
#    Transaction type Sale type  Sales channel   POS location Billing country  \
# 17          product     order  Point of Sale  Boutique Site             NaN
# 30          product     order  Point of Sale  Boutique Site             NaN
# 64          unknown    return   Online Store            NaN   United States
# 65          product    return   Online Store            NaN   United States
# 66          unknown    return   Online Store            NaN   United States
#
#    Billing region Billing city Shipping country Shipping region Shipping city  \
# ...

# %%
df[df['Returns']!=0].head()
# Out:
#          Order ID        Sale ID                       Date  Order  \
# 64  5552290000000 17444600000000  2024-01-12T18:45:22-05:00  #2098
# 65  5552290000000 17441200000000  2024-01-12T18:45:22-05:00  #2098
# 66  5552290000000 17441200000000  2024-01-12T18:45:22-05:00  #2098
# 244 5619390000000 17699900000000  2024-03-20T22:26:17-04:00  #2179
# 245 5619390000000 17699900000000  2024-03-20T22:26:17-04:00  #2179
#
#     Transaction type Sale type  Sales channel   POS location Billing country  \
# 64           unknown    return   Online Store            NaN   United States
# 65           product    return   Online Store            NaN   United States
# 66           unknown    return   Online Store            NaN   United States
# 244          product    return  Point of Sale  Boutique Site             NaN
# 245          product    return  Point of Sale  Boutique Site             NaN
#
#     Billing region Billing city Shipping country Shipping region  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          398 non-null    float64
#  1   Sale ID           398 non-null    float64
#  2   Date              398 non-null    object
#  3   Order             398 non-null    object
#  4   Transaction type  398 non-null    object
#  5   Sale type         398 non-null    object
#  6   Sales channel     398 non-null    object
#  7   POS location      371 non-null    object
#  8   Billing country   28 non-null     object
#  9   Billing region    28 non-null     object
#  10  Billing city      28 non-null     object
#  11  Shipping country  18 non-null     object
#  12  Shipping region   18 non-null     object
#  13  Shipping city     18 non-null     object
#  14  Product type      105 non-null    object
#  15  Product vendor    134 non-null    object
# ...

# %%
for col in df.columns:
    if col!='Date':
        print(f'Count of unique identifiers for {col}: {df[col].nunique()}')

# No column can be used as primary key
# Out:
# Count of unique identifiers for Order ID: 207
# Count of unique identifiers for Sale ID: 172
# Count of unique identifiers for Order: 230
# Count of unique identifiers for Transaction type: 4
# Count of unique identifiers for Sale type: 2
# Count of unique identifiers for Sales channel: 3
# Count of unique identifiers for POS location: 1
# Count of unique identifiers for Billing country: 2
# Count of unique identifiers for Billing region: 6
# Count of unique identifiers for Billing city: 14
# Count of unique identifiers for Shipping country: 2
# Count of unique identifiers for Shipping region: 5
# Count of unique identifiers for Shipping city: 5
# Count of unique identifiers for Product type: 21
# Count of unique identifiers for Product vendor: 12
# Count of unique identifiers for Product: 270
# Count of unique identifiers for Variant: 38
# Count of unique identifiers for Variant SKU: 64
# Count of unique identifiers for Net quantity: 5
# ...

# %%
for col in df.columns:
    if df[col].dtype == 'object' and col != 'Date' and col != 'Order':
        print(f'Unique values for {col}: {df[col].unique()}')
# Out:
# Unique values for Transaction type: ['product' 'shipping' 'unknown' 'gift_card']
# Unique values for Sale type: ['order' 'return']
# Unique values for Sales channel: ['Point of Sale' 'Online Store' 'Shop']
# Unique values for POS location: ['Boutique Site' nan]
# Unique values for Billing country: [nan 'United States' 'Canada']
# Unique values for Billing region: [nan 'Ohio' 'Arkansas' 'Kentucky' 'North Carolina' 'Ontario' 'Alabama']
# Unique values for Billing city: [nan 'Cincinnati' 'Bryant' 'Covington' 'Independence' 'Union' 'Lexington'
#  'Florence' 'Blue Ash' 'Ft. Mitchell' 'Crestview Hills' 'Charlotte'
#  'Fairfield' 'Toronto' 'Daphne']
# Unique values for Shipping country: [nan 'United States' 'Canada']
# Unique values for Shipping region: [nan 'Ohio' 'Arkansas' 'North Carolina' 'Ontario' 'Alabama']
# Unique values for Shipping city: [nan 'Blue Ash' 'Bryant' 'Charlotte' 'Toronto' 'Daphne']
# ...

# %% [markdown]
# ## Needs clarification:
# - What is  `Point of Sale` in `Sales channel`
# - Is billing region same as shipping region? What is difference?

# %% [markdown]
# ## Consider delete cols:
# - Billing country
# - Billing city
# - Shipping country
# - Shipping city

# %% [markdown]
# ## Needs to clean:
# **1. Product type**
# - Clean `sale` | `Sale` type to ['Athletics' '2 Piece Set' 'dresses' 'Accessories' 'Earrings'
#  'blazers' 'Apparel & Accessories' 'Pants' 'Shirts & Tops' 'Jumpsuit'
#  'Dress' 'Dresses' 'Bracelet' 'Coats & Jackets'
#  'Jumpsuits & Rompers' 'Shorts' 'Skirt Suits' 'Gift Card' 'Shirt']
